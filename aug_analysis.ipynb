# %%
import numpy as np
import pandas as pd
import soundfile as sf
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
import re

# %%
BASE_DIR = Path("aug_data/train_data")

# %%
FILENAME_PATTERN = re.compile(
    r"(class[01])_([a-zA-Z0-9]+)_(\d+)_(noise|fast|slow|chop)_(\d+)\.npy$"
)

def extract_aug_metadata(filepath: Path):
    match = FILENAME_PATTERN.match(filepath.name)
    if not match:
        print("skipped: ",str(filepath.name)," (invalid filename format)")
        return None

    class_name, speaker, recording_id, aug_type, segment_id = match.groups()
    
    try:
        mel = np.load(filepath)
    except Exception as e:
        print("load error:", filepath.name, e)
        return None

    if mel.ndim != 2:
        print("invalid mel shape:", filepath.name)
        return None

    return {
        "path": str(filepath),
        "dataset_split": filepath.parts[-2],
        "class_number": int(class_name[-1]),
        "class_name": class_name,
        "speaker": speaker,
        "recording_id": int(recording_id),
        "segment_id": int(segment_id),
        "augmentation": aug_type,
        "n_mels": mel.shape[0],
        "n_frames": mel.shape[1],
        "mean": float(np.mean(mel)),
        "std": float(np.std(mel)),
    }

# %%
rows = []
for f in BASE_DIR.rglob("*.npy"):
    meta = extract_aug_metadata(f)
    if meta:
        rows.append(meta)

df_aug = pd.DataFrame(rows)
print("Loaded augmented files:", df_aug.shape)
# Out:
# skipped:  class0_adele_1_000.npy  (invalid filename format)
# skipped:  class0_adele_1_001.npy  (invalid filename format)
# skipped:  class0_adele_1_002.npy  (invalid filename format)
# skipped:  class0_adele_1_003.npy  (invalid filename format)
# skipped:  class0_adele_1_004.npy  (invalid filename format)
# skipped:  class0_adele_1_005.npy  (invalid filename format)
# skipped:  class0_adele_1_006.npy  (invalid filename format)
# skipped:  class0_adele_1_007.npy  (invalid filename format)
# skipped:  class0_adele_1_008.npy  (invalid filename format)
# skipped:  class0_adele_1_009.npy  (invalid filename format)
# skipped:  class0_adele_1_010.npy  (invalid filename format)
# skipped:  class0_adele_1_011.npy  (invalid filename format)
# skipped:  class0_adele_1_012.npy  (invalid filename format)
# skipped:  class0_adele_1_013.npy  (invalid filename format)
# skipped:  class0_adele_1_014.npy  (invalid filename format)
# skipped:  class0_adele_1_015.npy  (invalid filename format)
# skipped:  class0_adele_1_016.npy  (invalid filename format)
# skipped:  class0_adele_1_017.npy  (invalid filename format)
# skipped:  class0_adele_1_018.npy  (invalid filename format)
# skipped:  class0_adele_2_000.npy  (invalid filename format)
# skipped:  class0_adele_2_001.npy  (invalid filename format)
# skipped:  class0_adele_2_002.npy  (invalid filename format)
# skipped:  class0_adele_2_003.npy  (invalid filename format)
# skipped:  class0_adele_2_004.npy  (invalid filename format)
# skipped:  class0_adele_2_005.npy  (invalid filename format)
# skipped:  class0_adele_2_006.npy  (invalid filename format)
# skipped:  class0_adele_2_007.npy  (invalid filename format)
# skipped:  class0_adele_2_008.npy  (invalid filename format)
# skipped:  class0_adele_2_009.npy  (invalid filename format)
# skipped:  class0_adele_2_010.npy  (invalid filename format)
# skipped:  class0_adele_2_011.npy  (invalid filename format)
# skipped:  class0_adele_2_012.npy  (invalid filename format)
# skipped:  class0_adele_2_013.npy  (invalid filename format)
# skipped:  class0_adele_2_014.npy  (invalid filename format)
# skipped:  class0_adele_2_015.npy  (invalid filename format)
# skipped:  class0_adele_2_016.npy  (invalid filename format)
# skipped:  class0_adele_2_017.npy  (invalid filename format)
# skipped:  class0_adele_2_018.npy  (invalid filename format)
# skipped:  class0_adele_2_019.npy  (invalid filename format)
# skipped:  class0_adele_2_020.npy  (invalid filename format)
# skipped:  class0_adele_3_000.npy  (invalid filename format)
# skipped:  class0_adele_3_001.npy  (invalid filename format)
# skipped:  class0_adele_3_002.npy  (invalid filename format)
# skipped:  class0_adele_3_003.npy  (invalid filename format)
# skipped:  class0_adele_3_004.npy  (invalid filename format)
# skipped:  class0_adele_3_005.npy  (invalid filename format)
# skipped:  class0_adele_3_006.npy  (invalid filename format)
# skipped:  class0_adele_3_007.npy  (invalid filename format)
# skipped:  class0_adele_3_008.npy  (invalid filename format)
# skipped:  class0_adele_3_009.npy  (invalid filename format)
# skipped:  class0_adele_3_010.npy  (invalid filename format)
# skipped:  class0_adele_3_011.npy  (invalid filename format)
# skipped:  class0_adele_3_012.npy  (invalid filename format)
# skipped:  class0_adele_3_013.npy  (invalid filename format)
# skipped:  class0_adele_3_014.npy  (invalid filename format)
# skipped:  class0_adele_3_015.npy  (invalid filename format)
# skipped:  class0_adele_3_016.npy  (invalid filename format)
# skipped:  class0_adele_3_017.npy  (invalid filename format)
# skipped:  class0_adele_3_018.npy  (invalid filename format)
# skipped:  class0_adele_3_019.npy  (invalid filename format)
# skipped:  class0_adele_3_020.npy  (invalid filename format)
# skipped:  class0_adele_4_000.npy  (invalid filename format)
# skipped:  class0_adele_4_001.npy  (invalid filename format)
# skipped:  class0_adele_4_002.npy  (invalid filename format)
# skipped:  class0_adele_4_003.npy  (invalid filename format)
# skipped:  class0_adele_4_004.npy  (invalid filename format)
# skipped:  class0_adele_4_005.npy  (invalid filename format)
# skipped:  class0_adele_4_006.npy  (invalid filename format)
# skipped:  class0_adele_4_007.npy  (invalid filename format)
# skipped:  class0_adele_4_008.npy  (invalid filename format)
# skipped:  class0_adele_4_009.npy  (invalid filename format)
# skipped:  class0_adele_4_010.npy  (invalid filename format)
# skipped:  class0_adele_4_011.npy  (invalid filename format)
# skipped:  class0_adele_4_012.npy  (invalid filename format)
# skipped:  class0_adele_4_013.npy  (invalid filename format)
# skipped:  class0_adele_4_014.npy  (invalid filename format)
# skipped:  class0_adele_4_015.npy  (invalid filename format)
# skipped:  class0_adele_4_016.npy  (invalid filename format)
# skipped:  class0_adele_4_017.npy  (invalid filename format)
# skipped:  class0_adele_4_018.npy  (invalid filename format)
# skipped:  class0_adele_4_019.npy  (invalid filename format)
# skipped:  class0_adele_5_000.npy  (invalid filename format)
# skipped:  class0_adele_5_001.npy  (invalid filename format)
# skipped:  class0_adele_5_002.npy  (invalid filename format)
# skipped:  class0_adele_5_003.npy  (invalid filename format)
# skipped:  class0_adele_5_004.npy  (invalid filename format)
# skipped:  class0_adele_5_005.npy  (invalid filename format)
# skipped:  class0_adele_5_006.npy  (invalid filename format)
# skipped:  class0_adele_5_007.npy  (invalid filename format)
# skipped:  class0_adele_5_008.npy  (invalid filename format)
# skipped:  class0_adele_5_009.npy  (invalid filename format)
# skipped:  class0_adele_5_010.npy  (invalid filename format)
# skipped:  class0_adele_5_011.npy  (invalid filename format)
# skipped:  class0_adele_5_012.npy  (invalid filename format)
# skipped:  class0_adele_5_013.npy  (invalid filename format)
# skipped:  class0_adele_5_014.npy  (invalid filename format)
# skipped:  class0_adele_5_015.npy  (invalid filename format)
# skipped:  class0_adele_5_016.npy  (invalid filename format)
# skipped:  class0_adele_5_017.npy  (invalid filename format)
# skipped:  class0_attenborough_1_000.npy  (invalid filename format)
# skipped:  class0_attenborough_1_001.npy  (invalid filename format)
# skipped:  class0_attenborough_1_002.npy  (invalid filename format)
# skipped:  class0_attenborough_1_003.npy  (invalid filename format)
# skipped:  class0_attenborough_1_004.npy  (invalid filename format)
# skipped:  class0_attenborough_1_005.npy  (invalid filename format)
# skipped:  class0_attenborough_1_006.npy  (invalid filename format)
# skipped:  class0_attenborough_1_007.npy  (invalid filename format)
# skipped:  class0_attenborough_1_008.npy  (invalid filename format)
# skipped:  class0_attenborough_1_009.npy  (invalid filename format)
# skipped:  class0_attenborough_1_010.npy  (invalid filename format)
# skipped:  class0_attenborough_1_011.npy  (invalid filename format)
# skipped:  class0_attenborough_1_012.npy  (invalid filename format)
# skipped:  class0_attenborough_1_013.npy  (invalid filename format)
# skipped:  class0_attenborough_1_014.npy  (invalid filename format)
# skipped:  class0_attenborough_1_015.npy  (invalid filename format)
# skipped:  class0_attenborough_1_016.npy  (invalid filename format)
# skipped:  class0_attenborough_1_017.npy  (invalid filename format)
# skipped:  class0_attenborough_1_018.npy  (invalid filename format)
# skipped:  class0_attenborough_1_019.npy  (invalid filename format)
# skipped:  class0_attenborough_1_020.npy  (invalid filename format)
# skipped:  class0_attenborough_1_021.npy  (invalid filename format)
# skipped:  class0_attenborough_1_022.npy  (invalid filename format)
# skipped:  class0_attenborough_1_023.npy  (invalid filename format)
# skipped:  class0_attenborough_2_000.npy  (invalid filename format)
# skipped:  class0_attenborough_2_001.npy  (invalid filename format)
# skipped:  class0_attenborough_2_002.npy  (invalid filename format)
# skipped:  class0_attenborough_2_003.npy  (invalid filename format)
# skipped:  class0_attenborough_2_004.npy  (invalid filename format)
# skipped:  class0_attenborough_2_005.npy  (invalid filename format)
# skipped:  class0_attenborough_2_006.npy  (invalid filename format)
# skipped:  class0_attenborough_2_007.npy  (invalid filename format)
# skipped:  class0_attenborough_2_008.npy  (invalid filename format)
# skipped:  class0_attenborough_2_009.npy  (invalid filename format)
# skipped:  class0_attenborough_2_010.npy  (invalid filename format)
# skipped:  class0_attenborough_2_011.npy  (invalid filename format)
# skipped:  class0_attenborough_2_012.npy  (invalid filename format)
# skipped:  class0_attenborough_2_013.npy  (invalid filename format)
# skipped:  class0_attenborough_2_014.npy  (invalid filename format)
# skipped:  class0_attenborough_2_015.npy  (invalid filename format)
# skipped:  class0_attenborough_2_016.npy  (invalid filename format)
# skipped:  class0_attenborough_2_017.npy  (invalid filename format)
# skipped:  class0_attenborough_2_018.npy  (invalid filename format)
# skipped:  class0_attenborough_3_000.npy  (invalid filename format)
# skipped:  class0_attenborough_3_001.npy  (invalid filename format)
# skipped:  class0_attenborough_3_002.npy  (invalid filename format)
# skipped:  class0_attenborough_3_003.npy  (invalid filename format)
# skipped:  class0_attenborough_3_004.npy  (invalid filename format)
# skipped:  class0_attenborough_3_005.npy  (invalid filename format)
# skipped:  class0_attenborough_3_006.npy  (invalid filename format)
# skipped:  class0_attenborough_3_007.npy  (invalid filename format)
# skipped:  class0_attenborough_3_008.npy  (invalid filename format)
# skipped:  class0_attenborough_3_009.npy  (invalid filename format)
# skipped:  class0_attenborough_3_010.npy  (invalid filename format)
# skipped:  class0_attenborough_3_011.npy  (invalid filename format)
# skipped:  class0_attenborough_3_012.npy  (invalid filename format)
# skipped:  class0_attenborough_3_013.npy  (invalid filename format)
# skipped:  class0_attenborough_3_014.npy  (invalid filename format)
# skipped:  class0_attenborough_3_015.npy  (invalid filename format)
# skipped:  class0_attenborough_3_016.npy  (invalid filename format)
# skipped:  class0_attenborough_3_017.npy  (invalid filename format)
# skipped:  class0_attenborough_3_018.npy  (invalid filename format)
# skipped:  class0_attenborough_3_019.npy  (invalid filename format)
# skipped:  class0_attenborough_3_020.npy  (invalid filename format)
# skipped:  class0_attenborough_3_021.npy  (invalid filename format)
# skipped:  class0_attenborough_3_022.npy  (invalid filename format)
# skipped:  class0_attenborough_4_000.npy  (invalid filename format)
# skipped:  class0_attenborough_4_001.npy  (invalid filename format)
# skipped:  class0_attenborough_4_002.npy  (invalid filename format)
# skipped:  class0_attenborough_4_003.npy  (invalid filename format)
# skipped:  class0_attenborough_4_004.npy  (invalid filename format)
# skipped:  class0_attenborough_4_005.npy  (invalid filename format)
# skipped:  class0_attenborough_4_006.npy  (invalid filename format)
# skipped:  class0_attenborough_4_007.npy  (invalid filename format)
# skipped:  class0_attenborough_4_008.npy  (invalid filename format)
# skipped:  class0_attenborough_4_009.npy  (invalid filename format)
# skipped:  class0_attenborough_4_010.npy  (invalid filename format)
# skipped:  class0_attenborough_4_011.npy  (invalid filename format)
# skipped:  class0_attenborough_4_012.npy  (invalid filename format)
# skipped:  class0_attenborough_4_013.npy  (invalid filename format)
# skipped:  class0_attenborough_4_014.npy  (invalid filename format)
# skipped:  class0_attenborough_4_015.npy  (invalid filename format)
# skipped:  class0_attenborough_4_016.npy  (invalid filename format)
# skipped:  class0_attenborough_4_017.npy  (invalid filename format)
# skipped:  class0_attenborough_4_018.npy  (invalid filename format)
# skipped:  class0_attenborough_4_019.npy  (invalid filename format)
# skipped:  class0_attenborough_4_020.npy  (invalid filename format)
# skipped:  class0_attenborough_5_000.npy  (invalid filename format)
# skipped:  class0_attenborough_5_001.npy  (invalid filename format)
# skipped:  class0_attenborough_5_002.npy  (invalid filename format)
# skipped:  class0_attenborough_5_003.npy  (invalid filename format)
# skipped:  class0_attenborough_5_004.npy  (invalid filename format)
# skipped:  class0_attenborough_5_005.npy  (invalid filename format)
# skipped:  class0_attenborough_5_006.npy  (invalid filename format)
# skipped:  class0_attenborough_5_007.npy  (invalid filename format)
# skipped:  class0_attenborough_5_008.npy  (invalid filename format)
# skipped:  class0_attenborough_5_009.npy  (invalid filename format)
# skipped:  class0_attenborough_5_010.npy  (invalid filename format)
# skipped:  class0_attenborough_5_011.npy  (invalid filename format)
# skipped:  class0_attenborough_5_012.npy  (invalid filename format)
# skipped:  class0_attenborough_5_013.npy  (invalid filename format)
# skipped:  class0_attenborough_5_014.npy  (invalid filename format)
# skipped:  class0_attenborough_5_015.npy  (invalid filename format)
# skipped:  class0_blanchett_1_000.npy  (invalid filename format)
# skipped:  class0_blanchett_1_001.npy  (invalid filename format)
# skipped:  class0_blanchett_1_002.npy  (invalid filename format)
# skipped:  class0_blanchett_1_003.npy  (invalid filename format)
# skipped:  class0_blanchett_1_004.npy  (invalid filename format)
# skipped:  class0_blanchett_1_005.npy  (invalid filename format)
# skipped:  class0_blanchett_1_006.npy  (invalid filename format)
# skipped:  class0_blanchett_1_007.npy  (invalid filename format)
# skipped:  class0_blanchett_1_008.npy  (invalid filename format)
# skipped:  class0_blanchett_1_009.npy  (invalid filename format)
# skipped:  class0_blanchett_1_010.npy  (invalid filename format)
# skipped:  class0_blanchett_1_011.npy  (invalid filename format)
# skipped:  class0_blanchett_1_012.npy  (invalid filename format)
# skipped:  class0_blanchett_1_013.npy  (invalid filename format)
# skipped:  class0_blanchett_1_014.npy  (invalid filename format)
# skipped:  class0_blanchett_1_015.npy  (invalid filename format)
# skipped:  class0_blanchett_1_016.npy  (invalid filename format)
# skipped:  class0_blanchett_2_000.npy  (invalid filename format)
# skipped:  class0_blanchett_2_001.npy  (invalid filename format)
# skipped:  class0_blanchett_2_002.npy  (invalid filename format)
# skipped:  class0_blanchett_2_003.npy  (invalid filename format)
# skipped:  class0_blanchett_2_004.npy  (invalid filename format)
# skipped:  class0_blanchett_2_005.npy  (invalid filename format)
# skipped:  class0_blanchett_2_006.npy  (invalid filename format)
# skipped:  class0_blanchett_2_007.npy  (invalid filename format)
# skipped:  class0_blanchett_2_008.npy  (invalid filename format)
# skipped:  class0_blanchett_2_009.npy  (invalid filename format)
# skipped:  class0_blanchett_2_010.npy  (invalid filename format)
# skipped:  class0_blanchett_2_011.npy  (invalid filename format)
# skipped:  class0_blanchett_2_012.npy  (invalid filename format)
# skipped:  class0_blanchett_2_013.npy  (invalid filename format)
# skipped:  class0_blanchett_2_014.npy  (invalid filename format)
# skipped:  class0_blanchett_2_015.npy  (invalid filename format)
# skipped:  class0_blanchett_2_016.npy  (invalid filename format)
# skipped:  class0_blanchett_2_017.npy  (invalid filename format)
# skipped:  class0_blanchett_2_018.npy  (invalid filename format)
# skipped:  class0_blanchett_3_000.npy  (invalid filename format)
# skipped:  class0_blanchett_3_001.npy  (invalid filename format)
# skipped:  class0_blanchett_3_002.npy  (invalid filename format)
# skipped:  class0_blanchett_3_003.npy  (invalid filename format)
# skipped:  class0_blanchett_3_004.npy  (invalid filename format)
# skipped:  class0_blanchett_3_005.npy  (invalid filename format)
# skipped:  class0_blanchett_3_006.npy  (invalid filename format)
# skipped:  class0_blanchett_3_007.npy  (invalid filename format)
# skipped:  class0_blanchett_3_008.npy  (invalid filename format)
# skipped:  class0_blanchett_3_009.npy  (invalid filename format)
# skipped:  class0_blanchett_3_010.npy  (invalid filename format)
# skipped:  class0_blanchett_3_011.npy  (invalid filename format)
# skipped:  class0_blanchett_3_012.npy  (invalid filename format)
# skipped:  class0_blanchett_3_013.npy  (invalid filename format)
# skipped:  class0_blanchett_3_014.npy  (invalid filename format)
# skipped:  class0_blanchett_3_015.npy  (invalid filename format)
# skipped:  class0_blanchett_3_016.npy  (invalid filename format)
# skipped:  class0_blanchett_3_017.npy  (invalid filename format)
# skipped:  class0_blanchett_3_018.npy  (invalid filename format)
# skipped:  class0_blanchett_3_019.npy  (invalid filename format)
# skipped:  class0_blanchett_3_020.npy  (invalid filename format)
# skipped:  class0_blanchett_3_021.npy  (invalid filename format)
# skipped:  class0_blanchett_3_022.npy  (invalid filename format)
# skipped:  class0_blanchett_3_023.npy  (invalid filename format)
# skipped:  class0_blanchett_3_024.npy  (invalid filename format)
# skipped:  class0_blanchett_3_025.npy  (invalid filename format)
# skipped:  class0_blanchett_3_026.npy  (invalid filename format)
# skipped:  class0_blanchett_3_027.npy  (invalid filename format)
# skipped:  class0_blanchett_3_028.npy  (invalid filename format)
# skipped:  class0_blanchett_3_029.npy  (invalid filename format)
# skipped:  class0_blanchett_3_030.npy  (invalid filename format)
# skipped:  class0_blanchett_3_031.npy  (invalid filename format)
# skipped:  class0_blanchett_3_032.npy  (invalid filename format)
# skipped:  class0_blanchett_3_033.npy  (invalid filename format)
# skipped:  class0_blanchett_3_034.npy  (invalid filename format)
# skipped:  class0_blanchett_3_035.npy  (invalid filename format)
# skipped:  class0_blanchett_3_036.npy  (invalid filename format)
# skipped:  class0_blanchett_3_037.npy  (invalid filename format)
# skipped:  class0_blanchett_3_038.npy  (invalid filename format)
# skipped:  class0_blanchett_3_039.npy  (invalid filename format)
# skipped:  class0_blanchett_3_040.npy  (invalid filename format)
# skipped:  class0_blanchett_3_041.npy  (invalid filename format)
# skipped:  class0_blanchett_3_042.npy  (invalid filename format)
# skipped:  class0_blanchett_3_043.npy  (invalid filename format)
# skipped:  class0_blanchett_3_044.npy  (invalid filename format)
# skipped:  class0_blanchett_3_045.npy  (invalid filename format)
# skipped:  class0_blanchett_3_046.npy  (invalid filename format)
# skipped:  class0_blanchett_3_047.npy  (invalid filename format)
# skipped:  class0_blanchett_3_048.npy  (invalid filename format)
# skipped:  class0_blanchett_3_049.npy  (invalid filename format)
# skipped:  class0_blanchett_3_050.npy  (invalid filename format)
# skipped:  class0_blanchett_3_051.npy  (invalid filename format)
# skipped:  class0_blanchett_3_052.npy  (invalid filename format)
# skipped:  class0_blanchett_3_053.npy  (invalid filename format)
# skipped:  class0_blanchett_3_054.npy  (invalid filename format)
# skipped:  class0_blanchett_3_055.npy  (invalid filename format)
# skipped:  class0_blanchett_3_056.npy  (invalid filename format)
# skipped:  class0_blanchett_3_057.npy  (invalid filename format)
# skipped:  class0_blanchett_3_058.npy  (invalid filename format)
# skipped:  class0_blanchett_3_059.npy  (invalid filename format)
# skipped:  class0_blanchett_3_060.npy  (invalid filename format)
# skipped:  class0_blanchett_3_061.npy  (invalid filename format)
# skipped:  class0_blanchett_3_062.npy  (invalid filename format)
# skipped:  class0_blanchett_3_063.npy  (invalid filename format)
# skipped:  class0_blanchett_3_064.npy  (invalid filename format)
# skipped:  class0_blanchett_3_065.npy  (invalid filename format)
# skipped:  class0_blanchett_3_066.npy  (invalid filename format)
# skipped:  class0_blanchett_3_067.npy  (invalid filename format)
# skipped:  class0_blanchett_3_068.npy  (invalid filename format)
# skipped:  class0_blanchett_3_069.npy  (invalid filename format)
# skipped:  class0_blanchett_3_070.npy  (invalid filename format)
# skipped:  class0_blanchett_3_071.npy  (invalid filename format)
# skipped:  class0_blanchett_3_072.npy  (invalid filename format)
# skipped:  class0_blanchett_3_073.npy  (invalid filename format)
# skipped:  class0_blanchett_3_074.npy  (invalid filename format)
# skipped:  class0_blanchett_3_075.npy  (invalid filename format)
# skipped:  class0_blanchett_3_076.npy  (invalid filename format)
# skipped:  class0_blanchett_3_077.npy  (invalid filename format)
# skipped:  class0_blanchett_3_078.npy  (invalid filename format)
# skipped:  class0_blanchett_3_079.npy  (invalid filename format)
# skipped:  class0_blanchett_3_080.npy  (invalid filename format)
# skipped:  class0_blanchett_3_081.npy  (invalid filename format)
# skipped:  class0_blanchett_3_082.npy  (invalid filename format)
# skipped:  class0_blanchett_3_083.npy  (invalid filename format)
# skipped:  class0_blanchett_3_084.npy  (invalid filename format)
# skipped:  class0_blanchett_3_085.npy  (invalid filename format)
# skipped:  class0_blanchett_3_086.npy  (invalid filename format)
# skipped:  class0_blanchett_3_087.npy  (invalid filename format)
# skipped:  class0_blanchett_3_088.npy  (invalid filename format)
# skipped:  class0_blanchett_3_089.npy  (invalid filename format)
# skipped:  class0_blanchett_3_090.npy  (invalid filename format)
# skipped:  class0_blanchett_3_091.npy  (invalid filename format)
# skipped:  class0_blanchett_3_092.npy  (invalid filename format)
# skipped:  class0_blanchett_3_093.npy  (invalid filename format)
# skipped:  class0_blanchett_3_094.npy  (invalid filename format)
# skipped:  class0_blanchett_3_095.npy  (invalid filename format)
# skipped:  class0_blanchett_3_096.npy  (invalid filename format)
# skipped:  class0_blanchett_3_097.npy  (invalid filename format)
# skipped:  class0_blanchett_3_098.npy  (invalid filename format)
# skipped:  class0_blanchett_3_099.npy  (invalid filename format)
# skipped:  class0_blanchett_3_100.npy  (invalid filename format)
# skipped:  class0_blanchett_3_101.npy  (invalid filename format)
# skipped:  class0_blanchett_3_102.npy  (invalid filename format)
# skipped:  class0_blanchett_3_103.npy  (invalid filename format)
# skipped:  class0_blanchett_3_104.npy  (invalid filename format)
# skipped:  class0_blanchett_3_105.npy  (invalid filename format)
# skipped:  class0_blanchett_3_106.npy  (invalid filename format)
# skipped:  class0_blanchett_3_107.npy  (invalid filename format)
# skipped:  class0_blanchett_3_108.npy  (invalid filename format)
# skipped:  class0_blanchett_3_109.npy  (invalid filename format)
# skipped:  class0_blanchett_3_110.npy  (invalid filename format)
# skipped:  class0_blanchett_3_111.npy  (invalid filename format)
# skipped:  class0_blanchett_3_112.npy  (invalid filename format)
# skipped:  class0_blanchett_3_113.npy  (invalid filename format)
# skipped:  class0_blanchett_3_114.npy  (invalid filename format)
# skipped:  class0_blanchett_3_115.npy  (invalid filename format)
# skipped:  class0_blanchett_3_116.npy  (invalid filename format)
# skipped:  class0_blanchett_3_117.npy  (invalid filename format)
# skipped:  class0_blanchett_3_118.npy  (invalid filename format)
# skipped:  class0_blanchett_3_119.npy  (invalid filename format)
# skipped:  class0_blanchett_3_120.npy  (invalid filename format)
# skipped:  class0_blanchett_3_121.npy  (invalid filename format)
# skipped:  class0_blanchett_3_122.npy  (invalid filename format)
# skipped:  class0_blanchett_3_123.npy  (invalid filename format)
# skipped:  class0_blanchett_3_124.npy  (invalid filename format)
# skipped:  class0_blanchett_3_125.npy  (invalid filename format)
# skipped:  class0_blanchett_3_126.npy  (invalid filename format)
# skipped:  class0_blanchett_3_127.npy  (invalid filename format)
# skipped:  class0_blanchett_3_128.npy  (invalid filename format)
# skipped:  class0_blanchett_3_129.npy  (invalid filename format)
# skipped:  class0_blanchett_3_130.npy  (invalid filename format)
# skipped:  class0_blanchett_3_131.npy  (invalid filename format)
# skipped:  class0_blanchett_3_132.npy  (invalid filename format)
# skipped:  class0_blanchett_3_133.npy  (invalid filename format)
# skipped:  class0_blanchett_3_134.npy  (invalid filename format)
# skipped:  class0_blanchett_3_135.npy  (invalid filename format)
# skipped:  class0_blanchett_3_136.npy  (invalid filename format)
# skipped:  class0_blanchett_3_137.npy  (invalid filename format)
# skipped:  class0_blanchett_3_138.npy  (invalid filename format)
# skipped:  class0_blanchett_3_139.npy  (invalid filename format)
# skipped:  class0_blanchett_3_140.npy  (invalid filename format)
# skipped:  class0_blanchett_3_141.npy  (invalid filename format)
# skipped:  class0_blanchett_3_142.npy  (invalid filename format)
# skipped:  class0_blanchett_3_143.npy  (invalid filename format)
# skipped:  class0_blanchett_3_144.npy  (invalid filename format)
# skipped:  class0_blanchett_3_145.npy  (invalid filename format)
# skipped:  class0_blanchett_3_146.npy  (invalid filename format)
# skipped:  class0_blanchett_3_147.npy  (invalid filename format)
# skipped:  class0_blanchett_3_148.npy  (invalid filename format)
# skipped:  class0_blanchett_3_149.npy  (invalid filename format)
# skipped:  class0_blanchett_3_150.npy  (invalid filename format)
# skipped:  class0_blanchett_3_151.npy  (invalid filename format)
# skipped:  class0_blanchett_3_152.npy  (invalid filename format)
# skipped:  class0_blanchett_3_153.npy  (invalid filename format)
# skipped:  class0_blanchett_3_154.npy  (invalid filename format)
# skipped:  class0_blanchett_3_155.npy  (invalid filename format)
# skipped:  class0_blanchett_3_156.npy  (invalid filename format)
# skipped:  class0_blanchett_3_157.npy  (invalid filename format)
# skipped:  class0_blanchett_3_158.npy  (invalid filename format)
# skipped:  class0_blanchett_3_159.npy  (invalid filename format)
# skipped:  class0_blanchett_3_160.npy  (invalid filename format)
# skipped:  class0_blanchett_3_161.npy  (invalid filename format)
# skipped:  class0_blanchett_3_162.npy  (invalid filename format)
# skipped:  class0_blanchett_3_163.npy  (invalid filename format)
# skipped:  class0_blanchett_3_164.npy  (invalid filename format)
# skipped:  class0_blanchett_3_165.npy  (invalid filename format)
# skipped:  class0_blanchett_3_166.npy  (invalid filename format)
# skipped:  class0_blanchett_3_167.npy  (invalid filename format)
# skipped:  class0_blanchett_3_168.npy  (invalid filename format)
# skipped:  class0_blanchett_3_169.npy  (invalid filename format)
# skipped:  class0_blanchett_3_170.npy  (invalid filename format)
# skipped:  class0_blanchett_3_171.npy  (invalid filename format)
# skipped:  class0_blanchett_3_172.npy  (invalid filename format)
# skipped:  class0_blanchett_3_173.npy  (invalid filename format)
# skipped:  class0_blanchett_3_174.npy  (invalid filename format)
# skipped:  class0_blanchett_3_175.npy  (invalid filename format)
# skipped:  class0_blanchett_3_176.npy  (invalid filename format)
# skipped:  class0_blanchett_3_177.npy  (invalid filename format)
# skipped:  class0_blanchett_3_178.npy  (invalid filename format)
# skipped:  class0_blanchett_3_179.npy  (invalid filename format)
# skipped:  class0_blanchett_3_180.npy  (invalid filename format)
# skipped:  class0_blanchett_3_181.npy  (invalid filename format)
# skipped:  class0_blanchett_3_182.npy  (invalid filename format)
# skipped:  class0_blanchett_3_183.npy  (invalid filename format)
# skipped:  class0_blanchett_3_184.npy  (invalid filename format)
# skipped:  class0_blanchett_3_185.npy  (invalid filename format)
# skipped:  class0_blanchett_3_186.npy  (invalid filename format)
# skipped:  class0_blanchett_3_187.npy  (invalid filename format)
# skipped:  class0_blanchett_3_188.npy  (invalid filename format)
# skipped:  class0_blanchett_3_189.npy  (invalid filename format)
# skipped:  class0_blanchett_3_190.npy  (invalid filename format)
# skipped:  class0_blanchett_3_191.npy  (invalid filename format)
# skipped:  class0_blanchett_3_192.npy  (invalid filename format)
# skipped:  class0_blanchett_3_193.npy  (invalid filename format)
# skipped:  class0_blanchett_3_194.npy  (invalid filename format)
# skipped:  class0_blanchett_3_195.npy  (invalid filename format)
# skipped:  class0_blanchett_3_196.npy  (invalid filename format)
# skipped:  class0_blanchett_3_197.npy  (invalid filename format)
# skipped:  class0_blanchett_3_198.npy  (invalid filename format)
# skipped:  class0_blanchett_3_199.npy  (invalid filename format)
# skipped:  class0_blanchett_3_200.npy  (invalid filename format)
# skipped:  class0_blanchett_3_201.npy  (invalid filename format)
# skipped:  class0_blanchett_3_202.npy  (invalid filename format)
# skipped:  class0_blanchett_3_203.npy  (invalid filename format)
# skipped:  class0_blanchett_3_204.npy  (invalid filename format)
# skipped:  class0_blanchett_3_205.npy  (invalid filename format)
# skipped:  class0_blanchett_3_206.npy  (invalid filename format)
# skipped:  class0_blanchett_3_207.npy  (invalid filename format)
# skipped:  class0_blanchett_3_208.npy  (invalid filename format)
# skipped:  class0_blanchett_3_209.npy  (invalid filename format)
# skipped:  class0_blanchett_3_210.npy  (invalid filename format)
# skipped:  class0_blanchett_3_211.npy  (invalid filename format)
# skipped:  class0_blanchett_3_212.npy  (invalid filename format)
# skipped:  class0_blanchett_3_213.npy  (invalid filename format)
# skipped:  class0_blanchett_3_214.npy  (invalid filename format)
# skipped:  class0_blanchett_3_215.npy  (invalid filename format)
# skipped:  class0_blanchett_3_216.npy  (invalid filename format)
# skipped:  class0_blanchett_3_217.npy  (invalid filename format)
# skipped:  class0_blanchett_3_218.npy  (invalid filename format)
# skipped:  class0_blanchett_3_219.npy  (invalid filename format)
# skipped:  class0_blanchett_3_220.npy  (invalid filename format)
# skipped:  class0_blanchett_3_221.npy  (invalid filename format)
# skipped:  class0_blanchett_3_222.npy  (invalid filename format)
# skipped:  class0_blanchett_3_223.npy  (invalid filename format)
# skipped:  class0_blanchett_3_224.npy  (invalid filename format)
# skipped:  class0_blanchett_3_225.npy  (invalid filename format)
# skipped:  class0_blanchett_3_226.npy  (invalid filename format)
# skipped:  class0_blanchett_3_227.npy  (invalid filename format)
# skipped:  class0_blanchett_3_228.npy  (invalid filename format)
# skipped:  class0_blanchett_3_229.npy  (invalid filename format)
# skipped:  class0_blanchett_3_230.npy  (invalid filename format)
# skipped:  class0_blanchett_3_231.npy  (invalid filename format)
# skipped:  class0_blanchett_3_232.npy  (invalid filename format)
# skipped:  class0_blanchett_3_233.npy  (invalid filename format)
# skipped:  class0_blanchett_3_234.npy  (invalid filename format)
# skipped:  class0_blanchett_3_235.npy  (invalid filename format)
# skipped:  class0_blanchett_3_236.npy  (invalid filename format)
# skipped:  class0_blanchett_3_237.npy  (invalid filename format)
# skipped:  class0_blanchett_3_238.npy  (invalid filename format)
# skipped:  class0_blanchett_3_239.npy  (invalid filename format)
# skipped:  class0_blanchett_3_240.npy  (invalid filename format)
# skipped:  class0_blanchett_3_241.npy  (invalid filename format)
# skipped:  class0_blanchett_3_242.npy  (invalid filename format)
# skipped:  class0_blanchett_3_243.npy  (invalid filename format)
# skipped:  class0_blanchett_3_244.npy  (invalid filename format)
# skipped:  class0_blanchett_3_245.npy  (invalid filename format)
# skipped:  class0_blanchett_3_246.npy  (invalid filename format)
# skipped:  class0_blanchett_3_247.npy  (invalid filename format)
# skipped:  class0_blanchett_3_248.npy  (invalid filename format)
# skipped:  class0_blanchett_3_249.npy  (invalid filename format)
# skipped:  class0_blanchett_3_250.npy  (invalid filename format)
# skipped:  class0_blanchett_3_251.npy  (invalid filename format)
# skipped:  class0_blanchett_3_252.npy  (invalid filename format)
# skipped:  class0_blanchett_3_253.npy  (invalid filename format)
# skipped:  class0_blanchett_3_254.npy  (invalid filename format)
# skipped:  class0_blanchett_3_255.npy  (invalid filename format)
# skipped:  class0_blanchett_3_256.npy  (invalid filename format)
# skipped:  class0_blanchett_3_257.npy  (invalid filename format)
# skipped:  class0_blanchett_3_258.npy  (invalid filename format)
# skipped:  class0_blanchett_3_259.npy  (invalid filename format)
# skipped:  class0_blanchett_3_260.npy  (invalid filename format)
# skipped:  class0_blanchett_3_261.npy  (invalid filename format)
# skipped:  class0_blanchett_3_262.npy  (invalid filename format)
# skipped:  class0_blanchett_3_263.npy  (invalid filename format)
# skipped:  class0_blanchett_3_264.npy  (invalid filename format)
# skipped:  class0_blanchett_3_265.npy  (invalid filename format)
# skipped:  class0_blanchett_3_266.npy  (invalid filename format)
# skipped:  class0_blanchett_3_267.npy  (invalid filename format)
# skipped:  class0_blanchett_3_268.npy  (invalid filename format)
# skipped:  class0_blanchett_3_269.npy  (invalid filename format)
# skipped:  class0_blanchett_3_270.npy  (invalid filename format)
# skipped:  class0_blanchett_3_271.npy  (invalid filename format)
# skipped:  class0_blanchett_3_272.npy  (invalid filename format)
# skipped:  class0_blanchett_3_273.npy  (invalid filename format)
# skipped:  class0_blanchett_3_274.npy  (invalid filename format)
# skipped:  class0_blanchett_3_275.npy  (invalid filename format)
# skipped:  class0_blanchett_3_276.npy  (invalid filename format)
# skipped:  class0_blanchett_3_277.npy  (invalid filename format)
# skipped:  class0_blanchett_3_278.npy  (invalid filename format)
# skipped:  class0_blanchett_3_279.npy  (invalid filename format)
# skipped:  class0_blanchett_3_280.npy  (invalid filename format)
# skipped:  class0_blanchett_3_281.npy  (invalid filename format)
# skipped:  class0_blanchett_3_282.npy  (invalid filename format)
# skipped:  class0_blanchett_3_283.npy  (invalid filename format)
# skipped:  class0_blanchett_3_284.npy  (invalid filename format)
# skipped:  class0_blanchett_3_285.npy  (invalid filename format)
# skipped:  class0_blanchett_3_286.npy  (invalid filename format)
# skipped:  class0_blanchett_3_287.npy  (invalid filename format)
# skipped:  class0_blanchett_3_288.npy  (invalid filename format)
# skipped:  class0_blanchett_3_289.npy  (invalid filename format)
# skipped:  class0_blanchett_3_290.npy  (invalid filename format)
# skipped:  class0_blanchett_3_291.npy  (invalid filename format)
# skipped:  class0_blanchett_3_292.npy  (invalid filename format)
# skipped:  class0_blanchett_3_293.npy  (invalid filename format)
# skipped:  class0_blanchett_3_294.npy  (invalid filename format)
# skipped:  class0_blanchett_3_295.npy  (invalid filename format)
# skipped:  class0_blanchett_3_296.npy  (invalid filename format)
# skipped:  class0_blanchett_3_297.npy  (invalid filename format)
# skipped:  class0_blanchett_3_298.npy  (invalid filename format)
# skipped:  class0_blanchett_3_299.npy  (invalid filename format)
# skipped:  class0_blanchett_3_300.npy  (invalid filename format)
# skipped:  class0_blanchett_3_301.npy  (invalid filename format)
# skipped:  class0_blanchett_3_302.npy  (invalid filename format)
# skipped:  class0_blanchett_3_303.npy  (invalid filename format)
# skipped:  class0_blanchett_3_304.npy  (invalid filename format)
# skipped:  class0_blanchett_3_305.npy  (invalid filename format)
# skipped:  class0_blanchett_3_306.npy  (invalid filename format)
# skipped:  class0_blanchett_3_307.npy  (invalid filename format)
# skipped:  class0_blanchett_3_308.npy  (invalid filename format)
# skipped:  class0_blanchett_3_309.npy  (invalid filename format)
# skipped:  class0_blanchett_3_310.npy  (invalid filename format)
# skipped:  class0_blanchett_3_311.npy  (invalid filename format)
# skipped:  class0_blanchett_3_312.npy  (invalid filename format)
# skipped:  class0_blanchett_3_313.npy  (invalid filename format)
# skipped:  class0_blanchett_3_314.npy  (invalid filename format)
# skipped:  class0_blanchett_3_315.npy  (invalid filename format)
# skipped:  class0_blanchett_3_316.npy  (invalid filename format)
# skipped:  class0_blanchett_3_317.npy  (invalid filename format)
# skipped:  class0_blanchett_3_318.npy  (invalid filename format)
# skipped:  class0_blanchett_3_319.npy  (invalid filename format)
# skipped:  class0_blanchett_3_320.npy  (invalid filename format)
# skipped:  class0_blanchett_3_321.npy  (invalid filename format)
# skipped:  class0_blanchett_3_322.npy  (invalid filename format)
# skipped:  class0_blanchett_3_323.npy  (invalid filename format)
# skipped:  class0_blanchett_3_324.npy  (invalid filename format)
# skipped:  class0_blanchett_3_325.npy  (invalid filename format)
# skipped:  class0_blanchett_3_326.npy  (invalid filename format)
# skipped:  class0_blanchett_3_327.npy  (invalid filename format)
# skipped:  class0_blanchett_3_328.npy  (invalid filename format)
# skipped:  class0_blanchett_3_329.npy  (invalid filename format)
# skipped:  class0_blanchett_3_330.npy  (invalid filename format)
# skipped:  class0_blanchett_3_331.npy  (invalid filename format)
# skipped:  class0_blanchett_3_332.npy  (invalid filename format)
# skipped:  class0_blanchett_3_333.npy  (invalid filename format)
# skipped:  class0_blanchett_3_334.npy  (invalid filename format)
# skipped:  class0_blanchett_3_335.npy  (invalid filename format)
# skipped:  class0_blanchett_3_336.npy  (invalid filename format)
# skipped:  class0_blanchett_3_337.npy  (invalid filename format)
# skipped:  class0_blanchett_3_338.npy  (invalid filename format)
# skipped:  class0_blanchett_3_339.npy  (invalid filename format)
# skipped:  class0_blanchett_3_340.npy  (invalid filename format)
# skipped:  class0_blanchett_3_341.npy  (invalid filename format)
# skipped:  class0_blanchett_3_342.npy  (invalid filename format)
# skipped:  class0_blanchett_3_343.npy  (invalid filename format)
# skipped:  class0_blanchett_3_344.npy  (invalid filename format)
# skipped:  class0_blanchett_3_345.npy  (invalid filename format)
# skipped:  class0_blanchett_3_346.npy  (invalid filename format)
# skipped:  class0_blanchett_3_347.npy  (invalid filename format)
# skipped:  class0_blanchett_3_348.npy  (invalid filename format)
# skipped:  class0_blanchett_3_349.npy  (invalid filename format)
# skipped:  class0_blanchett_3_350.npy  (invalid filename format)
# skipped:  class0_blanchett_4_000.npy  (invalid filename format)
# skipped:  class0_blanchett_4_001.npy  (invalid filename format)
# skipped:  class0_blanchett_4_002.npy  (invalid filename format)
# skipped:  class0_blanchett_4_003.npy  (invalid filename format)
# skipped:  class0_blanchett_4_004.npy  (invalid filename format)
# skipped:  class0_blanchett_4_005.npy  (invalid filename format)
# skipped:  class0_blanchett_4_006.npy  (invalid filename format)
# skipped:  class0_blanchett_4_007.npy  (invalid filename format)
# skipped:  class0_blanchett_4_008.npy  (invalid filename format)
# skipped:  class0_blanchett_4_009.npy  (invalid filename format)
# skipped:  class0_blanchett_4_010.npy  (invalid filename format)
# skipped:  class0_blanchett_4_011.npy  (invalid filename format)
# skipped:  class0_blanchett_4_012.npy  (invalid filename format)
# skipped:  class0_blanchett_4_013.npy  (invalid filename format)
# skipped:  class0_blanchett_4_014.npy  (invalid filename format)
# skipped:  class0_blanchett_4_015.npy  (invalid filename format)
# skipped:  class0_blanchett_4_016.npy  (invalid filename format)
# skipped:  class0_blanchett_4_017.npy  (invalid filename format)
# skipped:  class0_blanchett_4_018.npy  (invalid filename format)
# skipped:  class0_blanchett_4_019.npy  (invalid filename format)
# skipped:  class0_blanchett_4_020.npy  (invalid filename format)
# skipped:  class0_blanchett_5_000.npy  (invalid filename format)
# skipped:  class0_blanchett_5_001.npy  (invalid filename format)
# skipped:  class0_blanchett_5_002.npy  (invalid filename format)
# skipped:  class0_blanchett_5_003.npy  (invalid filename format)
# skipped:  class0_blanchett_5_004.npy  (invalid filename format)
# skipped:  class0_blanchett_5_005.npy  (invalid filename format)
# skipped:  class0_blanchett_5_006.npy  (invalid filename format)
# skipped:  class0_blanchett_5_007.npy  (invalid filename format)
# skipped:  class0_blanchett_5_008.npy  (invalid filename format)
# skipped:  class0_blanchett_5_009.npy  (invalid filename format)
# skipped:  class0_blanchett_5_010.npy  (invalid filename format)
# skipped:  class0_blanchett_5_011.npy  (invalid filename format)
# skipped:  class0_blanchett_5_012.npy  (invalid filename format)
# skipped:  class0_blanchett_5_013.npy  (invalid filename format)
# skipped:  class0_blanchett_5_014.npy  (invalid filename format)
# skipped:  class0_blanchett_5_015.npy  (invalid filename format)
# skipped:  class0_blanchett_5_016.npy  (invalid filename format)
# skipped:  class0_blanchett_5_017.npy  (invalid filename format)
# skipped:  class0_blanchett_5_018.npy  (invalid filename format)
# skipped:  class0_blanchett_5_019.npy  (invalid filename format)
# skipped:  class0_blanchett_5_020.npy  (invalid filename format)
# skipped:  class0_blanchett_5_021.npy  (invalid filename format)
# skipped:  class0_cruise_1_000.npy  (invalid filename format)
# skipped:  class0_cruise_1_001.npy  (invalid filename format)
# skipped:  class0_cruise_1_002.npy  (invalid filename format)
# skipped:  class0_cruise_1_003.npy  (invalid filename format)
# skipped:  class0_cruise_1_004.npy  (invalid filename format)
# skipped:  class0_cruise_1_005.npy  (invalid filename format)
# skipped:  class0_cruise_1_006.npy  (invalid filename format)
# skipped:  class0_cruise_1_007.npy  (invalid filename format)
# skipped:  class0_cruise_1_008.npy  (invalid filename format)
# skipped:  class0_cruise_1_009.npy  (invalid filename format)
# skipped:  class0_cruise_1_010.npy  (invalid filename format)
# skipped:  class0_cruise_1_011.npy  (invalid filename format)
# skipped:  class0_cruise_1_012.npy  (invalid filename format)
# skipped:  class0_cruise_1_013.npy  (invalid filename format)
# skipped:  class0_cruise_1_014.npy  (invalid filename format)
# skipped:  class0_cruise_1_015.npy  (invalid filename format)
# skipped:  class0_cruise_2_000.npy  (invalid filename format)
# skipped:  class0_cruise_2_001.npy  (invalid filename format)
# skipped:  class0_cruise_2_002.npy  (invalid filename format)
# skipped:  class0_cruise_2_003.npy  (invalid filename format)
# skipped:  class0_cruise_2_004.npy  (invalid filename format)
# skipped:  class0_cruise_2_005.npy  (invalid filename format)
# skipped:  class0_cruise_2_006.npy  (invalid filename format)
# skipped:  class0_cruise_2_007.npy  (invalid filename format)
# skipped:  class0_cruise_2_008.npy  (invalid filename format)
# skipped:  class0_cruise_2_009.npy  (invalid filename format)
# skipped:  class0_cruise_2_010.npy  (invalid filename format)
# skipped:  class0_cruise_2_011.npy  (invalid filename format)
# skipped:  class0_cruise_2_012.npy  (invalid filename format)
# skipped:  class0_cruise_3_000.npy  (invalid filename format)
# skipped:  class0_cruise_3_001.npy  (invalid filename format)
# skipped:  class0_cruise_3_002.npy  (invalid filename format)
# skipped:  class0_cruise_3_003.npy  (invalid filename format)
# skipped:  class0_cruise_3_004.npy  (invalid filename format)
# skipped:  class0_cruise_3_005.npy  (invalid filename format)
# skipped:  class0_cruise_3_006.npy  (invalid filename format)
# skipped:  class0_cruise_3_007.npy  (invalid filename format)
# skipped:  class0_cruise_3_008.npy  (invalid filename format)
# skipped:  class0_cruise_3_009.npy  (invalid filename format)
# skipped:  class0_cruise_3_010.npy  (invalid filename format)
# skipped:  class0_cruise_3_011.npy  (invalid filename format)
# skipped:  class0_cruise_3_012.npy  (invalid filename format)
# skipped:  class0_cruise_3_013.npy  (invalid filename format)
# skipped:  class0_cruise_3_014.npy  (invalid filename format)
# skipped:  class0_cruise_3_015.npy  (invalid filename format)
# skipped:  class0_cruise_3_016.npy  (invalid filename format)
# skipped:  class0_cruise_3_017.npy  (invalid filename format)
# skipped:  class0_cruise_3_018.npy  (invalid filename format)
# skipped:  class0_cruise_3_019.npy  (invalid filename format)
# skipped:  class0_cruise_3_020.npy  (invalid filename format)
# skipped:  class0_cruise_4_000.npy  (invalid filename format)
# skipped:  class0_cruise_4_001.npy  (invalid filename format)
# skipped:  class0_cruise_4_002.npy  (invalid filename format)
# skipped:  class0_cruise_4_003.npy  (invalid filename format)
# skipped:  class0_cruise_4_004.npy  (invalid filename format)
# skipped:  class0_cruise_4_005.npy  (invalid filename format)
# skipped:  class0_cruise_4_006.npy  (invalid filename format)
# skipped:  class0_cruise_4_007.npy  (invalid filename format)
# skipped:  class0_cruise_4_008.npy  (invalid filename format)
# skipped:  class0_cruise_4_009.npy  (invalid filename format)
# skipped:  class0_cruise_4_010.npy  (invalid filename format)
# skipped:  class0_cruise_4_011.npy  (invalid filename format)
# skipped:  class0_cruise_4_012.npy  (invalid filename format)
# skipped:  class0_cruise_4_013.npy  (invalid filename format)
# skipped:  class0_cruise_4_014.npy  (invalid filename format)
# skipped:  class0_cruise_5_000.npy  (invalid filename format)
# skipped:  class0_cruise_5_001.npy  (invalid filename format)
# skipped:  class0_cruise_5_002.npy  (invalid filename format)
# skipped:  class0_cruise_5_003.npy  (invalid filename format)
# skipped:  class0_cruise_5_004.npy  (invalid filename format)
# skipped:  class0_cruise_5_005.npy  (invalid filename format)
# skipped:  class0_cruise_5_006.npy  (invalid filename format)
# skipped:  class0_cruise_5_007.npy  (invalid filename format)
# skipped:  class0_cruise_5_008.npy  (invalid filename format)
# skipped:  class0_cruise_5_009.npy  (invalid filename format)
# skipped:  class0_cruise_5_010.npy  (invalid filename format)
# skipped:  class0_cruise_5_011.npy  (invalid filename format)
# skipped:  class0_cruise_5_012.npy  (invalid filename format)
# skipped:  class0_cruise_5_013.npy  (invalid filename format)
# skipped:  class0_cruise_5_014.npy  (invalid filename format)
# skipped:  class0_cruise_5_015.npy  (invalid filename format)
# skipped:  class0_cruise_5_016.npy  (invalid filename format)
# skipped:  class0_cruise_5_017.npy  (invalid filename format)
# skipped:  class0_cruise_5_018.npy  (invalid filename format)
# skipped:  class0_ellen_1_000.npy  (invalid filename format)
# skipped:  class0_ellen_1_001.npy  (invalid filename format)
# skipped:  class0_ellen_1_002.npy  (invalid filename format)
# skipped:  class0_ellen_1_003.npy  (invalid filename format)
# skipped:  class0_ellen_1_004.npy  (invalid filename format)
# skipped:  class0_ellen_1_005.npy  (invalid filename format)
# skipped:  class0_ellen_1_006.npy  (invalid filename format)
# skipped:  class0_ellen_1_007.npy  (invalid filename format)
# skipped:  class0_ellen_1_008.npy  (invalid filename format)
# skipped:  class0_ellen_1_009.npy  (invalid filename format)
# skipped:  class0_ellen_1_010.npy  (invalid filename format)
# skipped:  class0_ellen_1_011.npy  (invalid filename format)
# skipped:  class0_ellen_1_012.npy  (invalid filename format)
# skipped:  class0_ellen_1_013.npy  (invalid filename format)
# skipped:  class0_ellen_1_014.npy  (invalid filename format)
# skipped:  class0_ellen_1_015.npy  (invalid filename format)
# skipped:  class0_ellen_1_016.npy  (invalid filename format)
# skipped:  class0_ellen_1_017.npy  (invalid filename format)
# skipped:  class0_ellen_1_018.npy  (invalid filename format)
# skipped:  class0_ellen_1_019.npy  (invalid filename format)
# skipped:  class0_ellen_1_020.npy  (invalid filename format)
# skipped:  class0_ellen_1_021.npy  (invalid filename format)
# skipped:  class0_ellen_1_022.npy  (invalid filename format)
# skipped:  class0_ellen_1_023.npy  (invalid filename format)
# skipped:  class0_ellen_1_024.npy  (invalid filename format)
# skipped:  class0_ellen_1_025.npy  (invalid filename format)
# skipped:  class0_ellen_1_026.npy  (invalid filename format)
# skipped:  class0_ellen_1_027.npy  (invalid filename format)
# skipped:  class0_ellen_1_028.npy  (invalid filename format)
# skipped:  class0_ellen_1_029.npy  (invalid filename format)
# skipped:  class0_ellen_1_030.npy  (invalid filename format)
# skipped:  class0_ellen_2_000.npy  (invalid filename format)
# skipped:  class0_ellen_2_001.npy  (invalid filename format)
# skipped:  class0_ellen_2_002.npy  (invalid filename format)
# skipped:  class0_ellen_2_003.npy  (invalid filename format)
# skipped:  class0_ellen_2_004.npy  (invalid filename format)
# skipped:  class0_ellen_2_005.npy  (invalid filename format)
# skipped:  class0_ellen_2_006.npy  (invalid filename format)
# skipped:  class0_ellen_2_007.npy  (invalid filename format)
# skipped:  class0_ellen_2_008.npy  (invalid filename format)
# skipped:  class0_ellen_2_009.npy  (invalid filename format)
# ...
# skipped:  class1_trisha_13_009.npy  (invalid filename format)
# skipped:  class1_trisha_13_010.npy  (invalid filename format)
# skipped:  class1_trisha_13_011.npy  (invalid filename format)
# skipped:  class1_trisha_13_012.npy  (invalid filename format)
# skipped:  class1_trisha_13_013.npy  (invalid filename format)
# skipped:  class1_trisha_13_014.npy  (invalid filename format)
# skipped:  class1_trisha_13_015.npy  (invalid filename format)
# skipped:  class1_trisha_13_016.npy  (invalid filename format)
# skipped:  class1_trisha_13_017.npy  (invalid filename format)
# skipped:  class1_trisha_13_018.npy  (invalid filename format)
# skipped:  class1_trisha_13_019.npy  (invalid filename format)
# skipped:  class1_trisha_13_020.npy  (invalid filename format)
# skipped:  class1_trisha_13_021.npy  (invalid filename format)
# skipped:  class1_trisha_13_022.npy  (invalid filename format)
# skipped:  class1_trisha_13_023.npy  (invalid filename format)
# skipped:  class1_trisha_13_024.npy  (invalid filename format)
# skipped:  class1_trisha_13_025.npy  (invalid filename format)
# skipped:  class1_trisha_13_026.npy  (invalid filename format)
# skipped:  class1_trisha_13_027.npy  (invalid filename format)
# skipped:  class1_trisha_13_028.npy  (invalid filename format)
# skipped:  class1_trisha_13_029.npy  (invalid filename format)
# skipped:  class1_trisha_13_030.npy  (invalid filename format)
# skipped:  class1_trisha_13_031.npy  (invalid filename format)
# skipped:  class1_trisha_13_032.npy  (invalid filename format)
# skipped:  class1_trisha_15_000.npy  (invalid filename format)
# skipped:  class1_trisha_15_001.npy  (invalid filename format)
# skipped:  class1_trisha_15_002.npy  (invalid filename format)
# skipped:  class1_trisha_15_003.npy  (invalid filename format)
# skipped:  class1_trisha_15_004.npy  (invalid filename format)
# skipped:  class1_trisha_15_005.npy  (invalid filename format)
# skipped:  class1_trisha_15_006.npy  (invalid filename format)
# skipped:  class1_trisha_15_007.npy  (invalid filename format)
# skipped:  class1_trisha_15_008.npy  (invalid filename format)
# skipped:  class1_trisha_15_009.npy  (invalid filename format)
# skipped:  class1_trisha_15_010.npy  (invalid filename format)
# skipped:  class1_trisha_15_011.npy  (invalid filename format)
# skipped:  class1_trisha_15_012.npy  (invalid filename format)
# skipped:  class1_trisha_15_013.npy  (invalid filename format)
# skipped:  class1_trisha_15_014.npy  (invalid filename format)
# skipped:  class1_trisha_15_015.npy  (invalid filename format)
# skipped:  class1_trisha_15_016.npy  (invalid filename format)
# skipped:  class1_trisha_15_017.npy  (invalid filename format)
# skipped:  class1_trisha_15_018.npy  (invalid filename format)
# skipped:  class1_trisha_15_019.npy  (invalid filename format)
# skipped:  class1_trisha_15_020.npy  (invalid filename format)
# skipped:  class1_trisha_15_021.npy  (invalid filename format)
# skipped:  class1_trisha_15_022.npy  (invalid filename format)
# skipped:  class1_trisha_15_023.npy  (invalid filename format)
# skipped:  class1_trisha_15_024.npy  (invalid filename format)
# skipped:  class1_trisha_15_025.npy  (invalid filename format)
# skipped:  class1_trisha_15_026.npy  (invalid filename format)
# skipped:  class1_trisha_15_027.npy  (invalid filename format)
# skipped:  class1_trisha_15_028.npy  (invalid filename format)
# skipped:  class1_trisha_15_029.npy  (invalid filename format)
# skipped:  class1_trisha_2_000.npy  (invalid filename format)
# skipped:  class1_trisha_2_001.npy  (invalid filename format)
# skipped:  class1_trisha_2_002.npy  (invalid filename format)
# skipped:  class1_trisha_2_003.npy  (invalid filename format)
# skipped:  class1_trisha_2_004.npy  (invalid filename format)
# skipped:  class1_trisha_2_005.npy  (invalid filename format)
# skipped:  class1_trisha_2_006.npy  (invalid filename format)
# skipped:  class1_trisha_2_007.npy  (invalid filename format)
# skipped:  class1_trisha_2_008.npy  (invalid filename format)
# skipped:  class1_trisha_2_009.npy  (invalid filename format)
# skipped:  class1_trisha_2_010.npy  (invalid filename format)
# skipped:  class1_trisha_2_011.npy  (invalid filename format)
# skipped:  class1_trisha_2_012.npy  (invalid filename format)
# skipped:  class1_trisha_2_013.npy  (invalid filename format)
# skipped:  class1_trisha_2_014.npy  (invalid filename format)
# skipped:  class1_trisha_2_015.npy  (invalid filename format)
# skipped:  class1_trisha_2_016.npy  (invalid filename format)
# skipped:  class1_trisha_2_017.npy  (invalid filename format)
# skipped:  class1_trisha_3_000.npy  (invalid filename format)
# skipped:  class1_trisha_3_001.npy  (invalid filename format)
# skipped:  class1_trisha_3_002.npy  (invalid filename format)
# skipped:  class1_trisha_3_003.npy  (invalid filename format)
# skipped:  class1_trisha_3_004.npy  (invalid filename format)
# skipped:  class1_trisha_3_005.npy  (invalid filename format)
# skipped:  class1_trisha_3_006.npy  (invalid filename format)
# skipped:  class1_trisha_3_007.npy  (invalid filename format)
# skipped:  class1_trisha_3_008.npy  (invalid filename format)
# skipped:  class1_trisha_3_009.npy  (invalid filename format)
# skipped:  class1_trisha_3_010.npy  (invalid filename format)
# skipped:  class1_trisha_3_011.npy  (invalid filename format)
# skipped:  class1_trisha_3_012.npy  (invalid filename format)
# skipped:  class1_trisha_3_013.npy  (invalid filename format)
# skipped:  class1_trisha_3_014.npy  (invalid filename format)
# skipped:  class1_trisha_3_015.npy  (invalid filename format)
# skipped:  class1_trisha_3_016.npy  (invalid filename format)
# skipped:  class1_trisha_3_017.npy  (invalid filename format)
# skipped:  class1_trisha_3_018.npy  (invalid filename format)
# skipped:  class1_trisha_3_019.npy  (invalid filename format)
# skipped:  class1_trisha_3_020.npy  (invalid filename format)
# skipped:  class1_trisha_3_021.npy  (invalid filename format)
# skipped:  class1_trisha_3_022.npy  (invalid filename format)
# skipped:  class1_trisha_3_023.npy  (invalid filename format)
# skipped:  class1_trisha_3_024.npy  (invalid filename format)
# skipped:  class1_trisha_3_025.npy  (invalid filename format)
# skipped:  class1_trisha_3_026.npy  (invalid filename format)
# skipped:  class1_trisha_3_027.npy  (invalid filename format)
# skipped:  class1_trisha_3_028.npy  (invalid filename format)
# skipped:  class1_trisha_3_029.npy  (invalid filename format)
# skipped:  class1_trisha_3_030.npy  (invalid filename format)
# skipped:  class1_trisha_5_000.npy  (invalid filename format)
# skipped:  class1_trisha_5_001.npy  (invalid filename format)
# skipped:  class1_trisha_5_002.npy  (invalid filename format)
# skipped:  class1_trisha_5_003.npy  (invalid filename format)
# skipped:  class1_trisha_5_004.npy  (invalid filename format)
# skipped:  class1_trisha_5_005.npy  (invalid filename format)
# skipped:  class1_trisha_5_006.npy  (invalid filename format)
# skipped:  class1_trisha_5_007.npy  (invalid filename format)
# skipped:  class1_trisha_5_008.npy  (invalid filename format)
# skipped:  class1_trisha_5_009.npy  (invalid filename format)
# skipped:  class1_trisha_5_010.npy  (invalid filename format)
# skipped:  class1_trisha_5_011.npy  (invalid filename format)
# skipped:  class1_trisha_5_012.npy  (invalid filename format)
# skipped:  class1_trisha_5_013.npy  (invalid filename format)
# skipped:  class1_trisha_5_014.npy  (invalid filename format)
# skipped:  class1_trisha_5_015.npy  (invalid filename format)
# skipped:  class1_trisha_5_016.npy  (invalid filename format)
# skipped:  class1_trisha_5_017.npy  (invalid filename format)
# skipped:  class1_trisha_5_018.npy  (invalid filename format)
# skipped:  class1_trisha_5_019.npy  (invalid filename format)
# skipped:  class1_trisha_5_020.npy  (invalid filename format)
# skipped:  class1_trisha_5_021.npy  (invalid filename format)
# skipped:  class1_trisha_5_022.npy  (invalid filename format)
# skipped:  class1_trisha_5_023.npy  (invalid filename format)
# skipped:  class1_trisha_5_024.npy  (invalid filename format)
# skipped:  class1_trisha_5_025.npy  (invalid filename format)
# skipped:  class1_trisha_5_026.npy  (invalid filename format)
# skipped:  class1_trisha_5_027.npy  (invalid filename format)
# skipped:  class1_trisha_5_028.npy  (invalid filename format)
# skipped:  class1_trisha_5_029.npy  (invalid filename format)
# skipped:  class1_trisha_5_030.npy  (invalid filename format)
# skipped:  class1_trisha_5_031.npy  (invalid filename format)
# skipped:  class1_trisha_5_032.npy  (invalid filename format)
# skipped:  class1_trisha_5_033.npy  (invalid filename format)
# skipped:  class1_trisha_5_034.npy  (invalid filename format)
# skipped:  class1_trisha_5_035.npy  (invalid filename format)
# skipped:  class1_trisha_5_036.npy  (invalid filename format)
# skipped:  class1_trisha_5_037.npy  (invalid filename format)
# skipped:  class1_trisha_5_038.npy  (invalid filename format)
# skipped:  class1_trisha_5_039.npy  (invalid filename format)
# skipped:  class1_trisha_6_000.npy  (invalid filename format)
# skipped:  class1_trisha_6_001.npy  (invalid filename format)
# skipped:  class1_trisha_6_002.npy  (invalid filename format)
# skipped:  class1_trisha_6_003.npy  (invalid filename format)
# skipped:  class1_trisha_6_004.npy  (invalid filename format)
# skipped:  class1_trisha_6_005.npy  (invalid filename format)
# skipped:  class1_trisha_6_006.npy  (invalid filename format)
# skipped:  class1_trisha_6_007.npy  (invalid filename format)
# skipped:  class1_trisha_6_008.npy  (invalid filename format)
# skipped:  class1_trisha_6_009.npy  (invalid filename format)
# skipped:  class1_trisha_6_010.npy  (invalid filename format)
# skipped:  class1_trisha_6_011.npy  (invalid filename format)
# skipped:  class1_trisha_6_012.npy  (invalid filename format)
# skipped:  class1_trisha_6_013.npy  (invalid filename format)
# skipped:  class1_trisha_6_014.npy  (invalid filename format)
# skipped:  class1_trisha_6_015.npy  (invalid filename format)
# skipped:  class1_trisha_6_016.npy  (invalid filename format)
# skipped:  class1_trisha_6_017.npy  (invalid filename format)
# skipped:  class1_trisha_6_018.npy  (invalid filename format)
# skipped:  class1_trisha_6_019.npy  (invalid filename format)
# skipped:  class1_trisha_6_020.npy  (invalid filename format)
# skipped:  class1_trisha_6_021.npy  (invalid filename format)
# skipped:  class1_trisha_6_022.npy  (invalid filename format)
# skipped:  class1_trisha_6_023.npy  (invalid filename format)
# skipped:  class1_trisha_6_024.npy  (invalid filename format)
# skipped:  class1_trisha_6_025.npy  (invalid filename format)
# skipped:  class1_trisha_6_026.npy  (invalid filename format)
# skipped:  class1_trisha_6_027.npy  (invalid filename format)
# skipped:  class1_trisha_6_028.npy  (invalid filename format)
# skipped:  class1_trisha_6_029.npy  (invalid filename format)
# skipped:  class1_trisha_6_030.npy  (invalid filename format)
# skipped:  class1_trisha_6_031.npy  (invalid filename format)
# skipped:  class1_trisha_6_032.npy  (invalid filename format)
# skipped:  class1_trisha_6_033.npy  (invalid filename format)
# skipped:  class1_trisha_6_034.npy  (invalid filename format)
# skipped:  class1_trisha_6_035.npy  (invalid filename format)
# skipped:  class1_trisha_6_036.npy  (invalid filename format)
# skipped:  class1_trisha_6_037.npy  (invalid filename format)
# skipped:  class1_trisha_6_038.npy  (invalid filename format)
# skipped:  class1_trisha_6_039.npy  (invalid filename format)
# skipped:  class1_trisha_6_040.npy  (invalid filename format)
# skipped:  class1_trisha_6_041.npy  (invalid filename format)
# skipped:  class1_trisha_6_042.npy  (invalid filename format)
# skipped:  class1_trisha_6_043.npy  (invalid filename format)
# skipped:  class1_trisha_6_044.npy  (invalid filename format)
# skipped:  class1_trisha_6_045.npy  (invalid filename format)
# skipped:  class1_trisha_7_000.npy  (invalid filename format)
# skipped:  class1_trisha_7_001.npy  (invalid filename format)
# skipped:  class1_trisha_7_002.npy  (invalid filename format)
# skipped:  class1_trisha_7_003.npy  (invalid filename format)
# skipped:  class1_trisha_7_004.npy  (invalid filename format)
# skipped:  class1_trisha_7_005.npy  (invalid filename format)
# skipped:  class1_trisha_7_006.npy  (invalid filename format)
# skipped:  class1_trisha_7_007.npy  (invalid filename format)
# skipped:  class1_trisha_7_008.npy  (invalid filename format)
# skipped:  class1_trisha_7_009.npy  (invalid filename format)
# skipped:  class1_trisha_7_010.npy  (invalid filename format)
# skipped:  class1_trisha_7_011.npy  (invalid filename format)
# skipped:  class1_trisha_7_012.npy  (invalid filename format)
# skipped:  class1_trisha_7_013.npy  (invalid filename format)
# skipped:  class1_trisha_7_014.npy  (invalid filename format)
# skipped:  class1_trisha_7_015.npy  (invalid filename format)
# skipped:  class1_trisha_7_016.npy  (invalid filename format)
# skipped:  class1_trisha_7_017.npy  (invalid filename format)
# skipped:  class1_trisha_7_018.npy  (invalid filename format)
# skipped:  class1_trisha_7_019.npy  (invalid filename format)
# skipped:  class1_trisha_7_020.npy  (invalid filename format)
# skipped:  class1_trisha_7_021.npy  (invalid filename format)
# skipped:  class1_trisha_7_022.npy  (invalid filename format)
# skipped:  class1_trisha_7_023.npy  (invalid filename format)
# skipped:  class1_trisha_7_024.npy  (invalid filename format)
# skipped:  class1_trisha_7_025.npy  (invalid filename format)
# skipped:  class1_trisha_7_026.npy  (invalid filename format)
# skipped:  class1_trisha_7_027.npy  (invalid filename format)
# skipped:  class1_trisha_7_028.npy  (invalid filename format)
# skipped:  class1_trisha_7_029.npy  (invalid filename format)
# skipped:  class1_trisha_7_030.npy  (invalid filename format)
# skipped:  class1_trisha_7_031.npy  (invalid filename format)
# skipped:  class1_trisha_7_032.npy  (invalid filename format)
# skipped:  class1_trisha_7_033.npy  (invalid filename format)
# skipped:  class1_trisha_7_034.npy  (invalid filename format)
# skipped:  class1_trisha_7_035.npy  (invalid filename format)
# skipped:  class1_trisha_7_036.npy  (invalid filename format)
# skipped:  class1_trisha_7_037.npy  (invalid filename format)
# skipped:  class1_trisha_9_000.npy  (invalid filename format)
# skipped:  class1_trisha_9_001.npy  (invalid filename format)
# skipped:  class1_trisha_9_002.npy  (invalid filename format)
# skipped:  class1_trisha_9_003.npy  (invalid filename format)
# skipped:  class1_trisha_9_004.npy  (invalid filename format)
# skipped:  class1_trisha_9_005.npy  (invalid filename format)
# skipped:  class1_trisha_9_006.npy  (invalid filename format)
# skipped:  class1_trisha_9_007.npy  (invalid filename format)
# skipped:  class1_trisha_9_008.npy  (invalid filename format)
# skipped:  class1_trisha_9_009.npy  (invalid filename format)
# skipped:  class1_trisha_9_010.npy  (invalid filename format)
# skipped:  class1_trisha_9_011.npy  (invalid filename format)
# skipped:  class1_trisha_9_012.npy  (invalid filename format)
# skipped:  class1_trisha_9_013.npy  (invalid filename format)
# skipped:  class1_trisha_9_014.npy  (invalid filename format)
# skipped:  class1_trisha_9_015.npy  (invalid filename format)
# skipped:  class1_trisha_9_016.npy  (invalid filename format)
# skipped:  class1_trisha_9_017.npy  (invalid filename format)
# skipped:  class1_trisha_9_018.npy  (invalid filename format)
# skipped:  class1_trisha_9_019.npy  (invalid filename format)
# skipped:  class1_trisha_9_020.npy  (invalid filename format)
# skipped:  class1_trisha_9_021.npy  (invalid filename format)
# skipped:  class1_trisha_9_022.npy  (invalid filename format)
# skipped:  class1_trisha_9_023.npy  (invalid filename format)
# skipped:  class1_trisha_9_024.npy  (invalid filename format)
# skipped:  class1_trisha_9_025.npy  (invalid filename format)
# skipped:  class1_trisha_9_026.npy  (invalid filename format)
# skipped:  class1_trisha_9_027.npy  (invalid filename format)
# skipped:  class1_trisha_9_028.npy  (invalid filename format)
# skipped:  class1_trisha_9_029.npy  (invalid filename format)
# skipped:  class1_trisha_9_030.npy  (invalid filename format)
# skipped:  class1_trisha_9_031.npy  (invalid filename format)
# skipped:  class1_trisha_9_032.npy  (invalid filename format)
# Loaded augmented files: (15374, 12)

# %%
print("Number of duplicates:",df_aug.duplicated(
    subset=["speaker", "recording_id", "segment_id", "augmentation"]).sum())

print("\nUnique spectrogram shapes:")
print(df_aug[["n_mels", "n_frames"]].drop_duplicates())
# Out:
# Number of duplicates: 0
#
# Unique spectrogram shapes:
#    n_mels  n_frames
# 0      80       300

# %%
print("\nAugmentation count per class:")
ct = pd.crosstab(df_aug["class_name"], df_aug["augmentation"])
ct.loc["ALL"] = ct.sum()
print(ct)

ct = pd.crosstab(df_aug["augmentation"], df_aug["class_name"])

ct.plot(
    kind="bar",
    figsize=(8, 5)
)

plt.title("Augmentation counts per class")
plt.xlabel("Augmentation type")
plt.ylabel("Number of samples")
plt.legend(title="Class")
plt.tight_layout()
plt.show()

aug_sum = df_aug["augmentation"].value_counts()

plt.figure(figsize=(6, 4))
aug_sum.plot(kind="bar")

plt.title("Total augmentation counts (class0 + class1)")
plt.xlabel("Augmentation type")
plt.ylabel("Number of samples")
plt.tight_layout()
plt.show()
# Out:
# Augmentation count per class:
# augmentation  chop  fast  noise  slow
# class_name
# class0        2049  1627   2046  2473
# class1        1783  1426   1828  2142
# ALL           3832  3053   3874  4615

# %% [markdown]
# The differences in the number of augmented samples are due to the nature of each augmentation method. For example, the slow augmentation generates longer segments from the original audio, resulting in more samples, whereas fast produces shorter segments, leading to fewer samples overall.

# %%
summary = df_aug.groupby(["class_name", "augmentation"])[["mean", "std"]].mean().round(4)
print(summary)
# Out:
#                            mean     std
# class_name augmentation
# class0     chop         -0.0000  1.0002
#            fast         -0.0001  1.0003
#            noise         0.0005  0.9999
#            slow         -0.0001  1.0003
# class1     chop         -0.0000  1.0003
#            fast         -0.0001  1.0002
#            noise         0.0004  0.9999
#            slow         -0.0001  1.0003

# %% [markdown]
# The mean values of the augmented mel-spectrograms are all very close to zero, and the standard deviations are approximately one, indicating that the augmentations do not introduce any significant bias or scaling changes. This suggests that each augmentation type preserves the overall energy distribution of the original audio, ensuring that the dataset remains consistent for training.

# %%
plt.figure(figsize=(8, 4))
sns.histplot(
    data=df_aug,
    x="mean",
    hue="augmentation",
    bins=50,
    kde=True
)
plt.title("Mean mel-spectrogram value by augmentation (train)")
plt.xlabel("mean")
plt.ylabel("count")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(
    data=df_aug,
    x="std",
    hue="augmentation",
    bins=50,
    kde=True
)
plt.title("Standard deviation by augmentation (train)")
plt.xlabel("std")
plt.ylabel("count")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(data=df_aug, x="class_name", y="mean", hue="augmentation")
plt.title("Mean value per class (augmented train)")
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 4))
sns.boxplot(data=df_aug, x="class_name", y="std", hue="augmentation")
plt.title("STD per class (augmented train)")
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="whitegrid")

fig, axes = plt.subplots(1, 4, figsize=(16, 4), sharey=True)

for ax, aug in zip(axes, ["noise", "fast", "slow", "chop"]):
    sample = df_aug[df_aug["augmentation"] == aug].sample(1)
    mel = np.load(sample["path"].iloc[0])
    ax.imshow(mel, aspect="auto", origin="lower")
    ax.set_title(aug)
    ax.set_xlabel("Time frames")

axes[0].set_ylabel("Mel bins")
plt.suptitle("Example augmented mel-spectrograms (train)")
plt.tight_layout()
plt.show()
